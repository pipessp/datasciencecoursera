# %% [markdown]
# # My Jupyter Notebook in IBM Data Science Experience

# %% [markdown]
# **Tessa Hilpipre**
# Business/Systems Analyst I

# %% [markdown]
# *I am interested in data science because I have a passion for collecting information and making it into something that is workable and new. I love finding ways to make things efficient and data can be used to improve all projects by making every decision more informed and every customer better heard and understood.*

# %% [markdown]
# ### Printing a String value in a sentence

# %%
nov = "November"
print("I was born in "+nov)
# Out:
# I was born in November

# %% [markdown]
# x can represent any number of months, including but not limited to:
# * January
# * April
# * July
#
# To make it print one of these other months:
# 1. Define a variable about the month that should be entered.
# 2. Change "nov" to the new variable.
# 3. Run.
#
# If there are any errors, try searching for the issue on [Google](www.google.com).
